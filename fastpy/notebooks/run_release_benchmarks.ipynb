# %%
# %load_ext autoreload
# %autoreload 2

import os
from pprint import pprint
import matplotlib
# %matplotlib inline

from context import fastpy
from common import PROJECT_ROOT_PATH
from fastpy.evaluation import plotting
from fastpy.run.Runner import MultiBenchmarkRunner

# %% [markdown]
# # Run benchmarks
# Alongside with the python script in the fastPy root, this notebook can run issue benchmark runs.

# %% [markdown]
# ## Multiple-release benchmark runs

# %%
multi_bench_runner = MultiBenchmarkRunner(config_path=os.path.join(os.path.join(PROJECT_ROOT_PATH, 'config.json')))
tag_run_name_dict = multi_bench_runner.perform_runs(force_compile=False)
pprint(tag_run_name_dict)
# Out:
# Running benchmarks for tag v0.0.2...
# Running benchmarks for tag v0.0.3...
# Running benchmarks for tag v0.0.4...
# Running benchmarks for tag v0.0.5...
# Running benchmarks for tag v0.0.6...
# {'v0.0.2': 'run_2019-05-21_15-19-38-163691',
#  'v0.0.3': 'run_2019-05-21_15-25-05-998210',
#  'v0.0.4': 'run_2019-05-21_15-27-15-598590',
#  'v0.0.5': 'run_2019-05-21_15-29-25-404982',
#  'v0.0.6': 'run_2019-05-21_15-31-20-064711'}

# %% [markdown]
# ### Evaluation

# %%
out_parser_dict = plotting.prepare_multiple_out_parsers(tag_run_name_dict)
COLOR_MAP = 'cool'
plotting.mult_plot_runtime_performance(out_parser_dict, plot_type='performance', colormap=COLOR_MAP, reverse_legend=True)
plotting.mult_plot_runtime_performance(out_parser_dict, plot_type='mean_runtime', colormap=COLOR_MAP, reverse_legend=False)
# Out:
# Loading USER SPECIFIED run: run_2019-05-21_15-19-38-163691
# Loading USER SPECIFIED run: run_2019-05-21_15-25-05-998210
# Loading USER SPECIFIED run: run_2019-05-21_15-27-15-598590
# Loading USER SPECIFIED run: run_2019-05-21_15-29-25-404982
# Loading USER SPECIFIED run: run_2019-05-21_15-31-20-064711
# Plotting v0.0.2
# Plotting v0.0.3
# Plotting v0.0.4
# Plotting v0.0.5
# Plotting v0.0.6
# Plotting v0.0.2
# Plotting v0.0.3
# Plotting v0.0.4
# Plotting v0.0.5
# Plotting v0.0.6
